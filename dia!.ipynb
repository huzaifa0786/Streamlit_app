# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X=pd.read_csv("diabeties.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-e2844b7a977a> in <module>
#       1 X=pd.read_csv("diabeties.csv")
#       2 X=X.drop(["Outcome"],axis=1)
# ----> 3 Y=data.Outcome
#
# NameError: name 'data' is not defined

# %%
X.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
sns.histplot(X, x="Outcome", kde=True)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Count'>

# %%
plt.figure(figsize=(18,18))
sns.heatmap(X)
# Out:
# <AxesSubplot:>

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-d1dd963e90b8> in <module>
#       1 pie, ax = plt.subplots(figsize=[10,6])
#       2 labels = X.keys()
# ----> 3 plt.pie(X, autopct="%.1f%%", explode=[0.05]*4, labels=labels, pctdistance=0.5)
#       4 plt.title("Diabetes", fontsize=14)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2980         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2981         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
# -> 2982         **({"data": data} if data is not None else {}))
#    2983
#    2984
#
# ...
